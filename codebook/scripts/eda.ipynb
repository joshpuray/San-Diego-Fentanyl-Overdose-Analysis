# %% [markdown]
# # Exploratory Data Analysis

# %%
# Imports 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# Display all columns 
pd.set_option('display.max_columns', None)

# %%
# Accessing local database 
database_path = "/Users/jpuray/databases/medicalCases.db"
conn = sqlite3.connect(database_path)

# %% [markdown]
# ## 1) Cleaning the data

# %%
pd.read_sql(
    """
    SELECT DISTINCT [Opioid Related]
    FROM cases 
    """, conn)
# Out:
#     Opioid Related
# 0       Non-Opioid
# 1           Opioid
# 2  Opioid-Fentanyl
# 3   Non-Disclosure
# 4

# %%
cases = pd.read_sql(
    """
    SELECT *
    FROM cases
    WHERE [Opioid Related] = 'Opioid-Fentanyl'
    """, conn
)
cases
# Out:
#      Row Number  Year Quarter Age in Years  Death Date Security Status  \
# 0           286  1997      Q4           59  12/15/1997     Access Free
# 1           331  1997      Q1           39  01/23/1997     Access Free
# 2          2557  1998      Q1           41  02/09/1998     Access Free
# 3          2762  1998      Q2           36  04/10/1998     Access Free
# 4          4857  1999      Q3           36  07/07/1999     Access Free
# ...         ...   ...     ...          ...         ...             ...
# 3450      80391  2024      Q1           38  01/16/2024     Access Free
# 3451      80392  2024      Q1           40  01/22/2024     Access Free
# 3452      80393  2024      Q1           26  01/08/2024     Access Free
# 3453      80397  2024      Q1           52  02/15/2024     Access Free
# 3454      80399  2024      Q1           48  02/17/2024     Access Free
#
#       Gender   Race Ethnic Group (Standardized) Manner of Death  \
# 0     Female  White                       White        Accident
# 1       Male  White                       White        Accident
# 2       Male  White                       White        Accident
# 3       Male  White                       White        Accident
# 4       Male  White                       White        Accident
# ...      ...    ...                         ...             ...
# 3450  Female  White                       White        Accident
# 3451    Male  White                       White        Accident
# 3452    Male  White                       White        Accident
# 3453  Female  White                       White        Accident
# 3454    Male  White                       White        Accident
#
#              Manner Type   Manner Type (Standardized) Manner Sub Type  \
# 0             Medication  Drug - Medication - Alcohol
# 1     Alcohol-Medication  Drug - Medication - Alcohol
# 2             Medication  Drug - Medication - Alcohol
# 3                         Drug - Medication - Alcohol
# 4             Medication  Drug - Medication - Alcohol
# ...                  ...                          ...             ...
# 3450   Drug - Medication  Drug - Medication - Alcohol  Drugs of abuse
# 3451   Drug - Medication  Drug - Medication - Alcohol  Drugs of abuse
# 3452   Drug - Medication  Drug - Medication - Alcohol  Drugs of abuse
# 3453   Drug - Medication  Drug - Medication - Alcohol  Drugs of abuse
# 3454   Drug - Medication  Drug - Medication - Alcohol  Drugs of abuse
#
#      Manner Sub Type (Standardized)   Opioid Related  \
# 0                        Medication  Opioid-Fentanyl
# 1                        Medication  Opioid-Fentanyl
# 2                        Medication  Opioid-Fentanyl
# 3                        Medication  Opioid-Fentanyl
# 4                        Medication  Opioid-Fentanyl
# ...                             ...              ...
# 3450                 Drugs of Abuse  Opioid-Fentanyl
# 3451                 Drugs of Abuse  Opioid-Fentanyl
# 3452                 Drugs of Abuse  Opioid-Fentanyl
# 3453                 Drugs of Abuse  Opioid-Fentanyl
# 3454                 Drugs of Abuse  Opioid-Fentanyl
#
#      Coronado Bridge Related (Suicide Cases)  \
# 0                                      FALSE
# 1                                      FALSE
# 2                                      FALSE
# 3                                      FALSE
# 4                                      FALSE
# ...                                      ...
# 3450
# 3451
# 3452
# 3453
# 3454
#
#                                          Cause of Death  \
# 0                            Pending laboratory studies
# 1     Acute fentanyl, morphine, oxycodone & diazepam...
# 2                           Acute fentanyl intoxication
# 3                           Acute fentanyl intoxication
# 4     Anoxic encephalopathy due to: Therapeutic fent...
# ...                                                 ...
# 3450  Anoxic-ischemic encephalopathy due to: resusci...
# 3451  Complications of anoxic-ischemic encephalopath...
# 3452  Complications of anoxic-ischemic encephalopath...
# 3453  Anoxic encephalopathy due to: Resuscitated car...
# 3454  Anoxic encephalopathy due to: Resuscitated car...
#
#      Contributing Conditions  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ...                      ...
# 3450                    none
# 3451                    None
# 3452                    None
# 3453                    None
# 3454                    None
#
#                                     How Injury Occurred  Event Date  \
# 0     Self-administered overdose of amitriptyline & ...  12/15/1997
# 1     Self-administered overdose of fentanyl, morphi...   1/23/1997
# 2               Self-administered overdose of fentanyl.    2/9/1998
# 3               Self-administered overdose of fentanyl.   4/10/1998
# 4     Adverse reaction to medication while in hospital.   11/6/1998
# ...                                                 ...         ...
# 3450     Self-administered fentanyl and methamphetamine   1/10/2024
# 3451     self-administered fentanyl and methamphetamine   1/10/2024
# 3452                         Self-administered fentanyl   6/15/2023
# 3453         Self-administered fentanyl and amphetamine  02/10/2024
# 3454     Self-administered fentanyl and methamphetamine  02/06/2024
#
#        Event Time   Event Place                 Event Place Type Event City  \
# 0     10:30:00 PM  Undetermined                            Other
# 1      6:05:00 PM          Home                            Other
# 2      7:15:00 AM     Apartment                            Other
# 3      4:30:00 PM          Home                            Other
# 4                      Hospital                            Other
# ...           ...           ...                              ...        ...
# 3450      Unknown          Home                  Decedent's Home  San Diego
# 3451      Unknown          Home                  Decedent's Home   El Cajon
# 3452         1600          Home  General Location (Manual Entry)  Oceanside
# 3453      Unknown
# 3454      Unknown         Hotel  General Location (Manual Entry)  San Diego
#
#      Event Zip                                       Death Place  \
# 0                                   FOUND:  Home        (rental)
# 1                                       Paradise Valley Hospital
# 2                                                      Apartment
# 3                                                           Home
# 4                                        Palomar Continuing Care
# ...        ...                                               ...
# 3450     92114
# 3451     92019
# 3452     92054  Carmel Mountain Rehabilitation Healthcare Center
# 3453
# 3454     92109
#
#                      Death Place Type     Death City Death Zip     Res City  \
# 0                               Other    Lemon Grove     91945  Lemon Grove
# 1                               Other  National City     91950    San Diego
# 2                               Other       Lakeside     92040     Lakeside
# 3                               Other      Oceanside     92056    Oceanside
# 4                               Other      Escondido     92025    Oceanside
# ...                               ...            ...       ...          ...
# 3450                         Hospital        La Mesa     91942    Boulevard
# 3451                         Hospital        La Mesa     91942     El Cajon
# 3452  General Location (Manual Entry)      San Diego     92128       Sparks
# 3453                         Hospital        La Mesa     91942     Lakeside
# 3454                         Hospital       La Jolla     92037
#
#      Res Zip Age Group Option 1 Age Group Option 2 Age Group Option 3
# 0      91945           50 to 59           55 to 59           55 to 64
# 1      92114           30 to 39           35 to 39           35 to 44
# 2      92040           40 to 49           40 to 44           35 to 44
# 3      92056           30 to 39           35 to 39           35 to 44
# 4      92054           30 to 39           35 to 39           35 to 44
# ...      ...                ...                ...                ...
# 3450   91905           30 to 39           35 to 39           35 to 44
# 3451   92019           40 to 49           40 to 44           35 to 44
# 3452   74869           20 to 29           25 to 29           25 to 34
# 3453   92040           50 to 59           50 to 54           45 to 54
# 3454                   40 to 49           45 to 49           45 to 54
#
# [3455 rows x 34 columns]

# %%
# Filtering data for only Fentanyl deaths 
df = df[df['Opioid Related'] == 'Opioid-Fentanyl'] 

# Converting the Event Date and Event Time to datetime
#df['Event Date'] = df['Event Date'].apply(lambda x:  np.nan if x == 'Unk' else pd.to_datetime(x))
df['Event Time'] = df['Event Time'].apply(lambda x:  np.nan if x == 'Unk' else pd.to_datetime(x))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx:245, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/tslibs/np_datetime.pyx:614, in pandas._libs.tslibs.np_datetime.convert_reso()
#
# OverflowError: value too large
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[23], line 6
#       2 df = df[df['Opioid Related'] == 'Opioid-Fentanyl']
#       4 # Converting the Event Date and Event Time to datetime
#       5 #df['Event Date'] = df['Event Date'].apply(lambda x:  np.nan if x == 'Unk' else pd.to_datetime(x))
# ----> 6 df['Event Time'] = df['Event Time'].apply(lambda x:  np.nan if x == 'Unk' else pd.to_datetime(x))
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[23], line 6, in <lambda>(x)
#       2 df = df[df['Opioid Related'] == 'Opioid-Fentanyl']
#       4 # Converting the Event Date and Event Time to datetime
#       5 #df['Event Date'] = df['Event Date'].apply(lambda x:  np.nan if x == 'Unk' else pd.to_datetime(x))
# ----> 6 df['Event Time'] = df['Event Time'].apply(lambda x:  np.nan if x == 'Unk' else pd.to_datetime(x))
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:1084, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1082         result = convert_listlike(argc, format)
#    1083 else:
# -> 1084     result = convert_listlike(np.array([arg]), format)[0]
#    1085     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1086         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/core/tools/datetimes.py:455, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     452 if format is not None and format != "mixed":
#     453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#     458     yearfirst=yearfirst,
#     459     utc=utc,
#     460     errors=errors,
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#     467     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, allow_object)
#    2174 # if str-dtype, convert
#    2175 data = np.array(data, copy=False, dtype=np.object_)
# -> 2177 result, tz_parsed = tslib.array_to_datetime(
#    2178     data,
#    2179     errors=errors,
#    2180     utc=utc,
#    2181     dayfirst=dayfirst,
#    2182     yearfirst=yearfirst,
#    2183 )
#    2185 if tz_parsed is not None:
#    2186     # We can take a shortcut since the datetime64 numpy array
#    2187     #  is in UTC
#    2188     # Return i8 values to denote unix timestamps
#    2189     return result.view("i8"), tz_parsed
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:402, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:551, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/tslib.pyx:519, in pandas._libs.tslib.array_to_datetime()
#
# File ~/opt/anaconda3/envs/sd_fent/lib/python3.8/site-packages/pandas/_libs/tslibs/conversion.pyx:248, in pandas._libs.tslibs.conversion._TSObject.ensure_reso()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1127, at position 0

# %%
#
# Out:
# Row Number                                   int64
# Year                                         int64
# Quarter                                     object
# Age in Years                               float64
# Death Date                                  object
# Security Status                             object
# Gender                                      object
# Race                                        object
# Ethnic Group (Standardized)                 object
# Manner of Death                             object
# Manner Type                                 object
# Manner Type (Standardized)                  object
# Manner Sub Type                             object
# Manner Sub Type (Standardized)              object
# Opioid Related                              object
# Coronado Bridge Related (Suicide Cases)     object
# Cause of Death                              object
# Contributing Conditions                     object
# How Injury Occurred                         object
# Event Date                                  object
# Event Time                                  object
# Event Place                                 object
# Event Place Type                            object
# Event City                                  object
# Event Zip                                   object
# Death Place                                 object
# Death Place Type                            object
# Death City                                  object
# Death Zip                                   object
# Res City                                    object
# Res Zip                                     object
# Age Group Option 1                          object
# Age Group Option 2                          object
# Age Group Option 3                          object
# dtype: object

# %%
df.describe()
# Out:
#          Row Number         Year  Age in Years
# count   3322.000000  3322.000000   3321.000000
# mean   66350.892535  2020.221252     41.227341
# std    12425.172069     3.883906     13.500975
# min      286.000000  1997.000000      0.000000
# 25%    64132.250000  2020.000000     31.000000
# 50%    68537.500000  2021.000000     39.000000
# 75%    72982.750000  2022.000000     52.000000
# max    80353.000000  2023.000000     98.000000
